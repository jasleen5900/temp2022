# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('market.csv', parse_dates=True)

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# try isnull() and notnull()
df.isnull()
df.notnull()
# How many in each column
display(df.isnull().sum())
# How amny are empty in the entire dataset
df.isnull().sum().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64
# 0

# %%
#display(df.head(10))
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
display(df.head(10))
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
dates=df['Date'].unique()
dates
# Out:
# array(['1/1/2019', '1/10/2019', '1/11/2019', '1/12/2019', '1/13/2019',
#        '1/14/2019', '1/15/2019', '1/16/2019', '1/17/2019', '1/18/2019',
#        '1/19/2019', '1/2/2019', '1/20/2019', '1/21/2019', '1/22/2019',
#        '1/23/2019', '1/24/2019', '1/25/2019', '1/26/2019', '1/27/2019',
#        '1/28/2019', '1/29/2019', '1/3/2019', '1/30/2019', '1/31/2019',
#        '1/4/2019', '1/5/2019', '1/6/2019', '1/7/2019', '1/8/2019',
#        '1/9/2019', '2/1/2019', '2/10/2019', '2/11/2019', '2/12/2019',
#        '2/13/2019', '2/14/2019', '2/15/2019', '2/16/2019', '2/17/2019',
#        '2/18/2019', '2/19/2019', '2/2/2019', '2/20/2019', '2/21/2019',
#        '2/22/2019', '2/23/2019', '2/24/2019', '2/25/2019', '2/26/2019',
#        '2/27/2019', '2/28/2019', '2/3/2019', '2/4/2019', '2/5/2019',
#        '2/6/2019', '2/7/2019', '2/8/2019', '2/9/2019', '3/1/2019',
#        '3/10/2019', '3/11/2019', '3/12/2019', '3/13/2019', '3/14/2019',
# ...

# %%
df['Date'].value_counts()
# Out:
# 2/7/2019     20
# 2/15/2019    19
# 3/2/2019     18
# 3/14/2019    18
# 1/8/2019     18
#              ..
# 3/21/2019     6
# 3/17/2019     6
# 2/21/2019     6
# 1/4/2019      6
# 2/28/2019     6
# Name: Date, Length: 89, dtype: int64

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df = df.sort_values(by="Date")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 496  556-97-7101      C  Naypyitaw        Normal  Female
# 484  493-65-6248      C  Naypyitaw        Member  Female
# 567  651-88-7328      A     Yangon        Normal  Female
# 523  133-14-7229      C  Naypyitaw        Normal    Male
# 970  746-04-1077      B   Mandalay        Member  Female
# ..           ...    ...        ...           ...     ...
# 393  308-47-4913      A     Yangon        Member  Female
# 73   841-35-6630      C  Naypyitaw        Normal  Female
# 433  616-87-0016      B   Mandalay        Normal    Male
# 585  127-47-6963      A     Yangon        Normal    Male
# 84   360-39-5055      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 496  Electronic accessories       63.22         2   6.3220  132.7620
# 484       Sports and travel       36.98        10  18.4900  388.2900
# 567     Fashion accessories       65.74         9  29.5830  621.2430
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 496 to 84
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize= (12,6))
ax = sns.countplot(x = "Customer type", data = df)
ax.set_title("Type of customers", fontsize = 25)
ax.set_xlabel("Customer type", fontsize = 16)
ax.set_ylabel("Customer Count", fontsize = 16)
# Out:
# Text(0, 0.5, 'Customer Count')

# %%
df.groupby(['Customer type']). agg({'Total':'count'})
# Out:
#                Total
# Customer type
# Member           501
# Normal           499

# %%
plt.figure(figsize=(11,6))
plt.style.use('Solarize_Light2')
ax = sns.countplot(x = "Customer type", hue = "Branch", data = df)
ax.set_title(label = "Customer type in different branch", fontsize = 25)
ax.set_xlabel(xlabel = "Branches", fontsize = 16)
ax.set_ylabel(ylabel = "Customer Count", fontsize = 16)
# Out:
# Text(0, 0.5, 'Customer Count')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 496  556-97-7101      C  Naypyitaw        Normal  Female
# 484  493-65-6248      C  Naypyitaw        Member  Female
# 567  651-88-7328      A     Yangon        Normal  Female
# 523  133-14-7229      C  Naypyitaw        Normal    Male
# 970  746-04-1077      B   Mandalay        Member  Female
# ..           ...    ...        ...           ...     ...
# 393  308-47-4913      A     Yangon        Member  Female
# 73   841-35-6630      C  Naypyitaw        Normal  Female
# 433  616-87-0016      B   Mandalay        Normal    Male
# 585  127-47-6963      A     Yangon        Normal    Male
# 84   360-39-5055      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 496  Electronic accessories       63.22         2   6.3220  132.7620
# 484       Sports and travel       36.98        10  18.4900  388.2900
# 567     Fashion accessories       65.74         9  29.5830  621.2430
# ...

# %%
plt.figure(figsize=(11,6))
plt.style.use('Solarize_Light2')
ax = sns.countplot(x = "Customer type", hue = "City", data = df)
ax.set_title(label = "Customer type in different city", fontsize = 25)
ax.set_xlabel(xlabel = "City", fontsize = 16)
ax.set_ylabel(ylabel = "Customer Count", fontsize = 16)
# Out:
# Text(0, 0.5, 'Customer Count')

# %%
df.groupby(['City']). agg({'Total':'count'})
# Out:
#            Total
# City
# Mandalay     332
# Naypyitaw    328
# Yangon       340

# %%
df.groupby(['Gender']). agg({'Total':'count'})
# Out:
#         Total
# Gender
# Female    501
# Male      499

# %%
data1 = df.groupby(['Customer type', 'Gender']). agg({'Total':'count'})

# %%
data1
# Out:
#                       Total
# Customer type Gender
# Member        Female    261
#               Male      240
# Normal        Female    240
#               Male      259

# %%
sns.set(style='whitegrid')
ax = sns.lineplot(data=t2)

# %%
plt.figure(figsize=(11,6))
plt.style.use('Solarize_Light2')
ax = sns.countplot(x = "Customer type", hue = "Gender", data = df)
ax.set_title(label = "Customer type wrt gender", fontsize = 25)
ax.set_xlabel(xlabel = "data1", fontsize = 16)
ax.set_ylabel(ylabel = "Customer Count", fontsize = 16)
# Out:
# Text(0, 0.5, 'Customer Count')

# %%
sns.set()
table = pd.pivot_table(data=df,index = ['Date'], columns = ['Customer type'], values = 'gross margin percentage', aggfunc='count').plot()

# %%
table
# Out:
# Product line   Electronic accessories  Fashion accessories  \
# Customer type
# Member                             78                   86
# Normal                             92                   92
#
# Product line   Food and beverages  Health and beauty  Home and lifestyle  \
# Customer type
# Member                         94                 73                  83
# Normal                         80                 79                  77
#
# Product line   Sports and travel
# Customer type
# Member                        87
# Normal                        79

# %%
t1 = pd.pivot_table(data=df,index = ['Customer type'], columns = ['Product line'], values = 'Rating', aggfunc='mean')

# %%
t1
# Out:
# Product line   Electronic accessories  Fashion accessories  \
# Customer type
# Member                       6.950000             6.946512
# Normal                       6.903261             7.106522
#
# Product line   Food and beverages  Health and beauty  Home and lifestyle  \
# Customer type
# Member                   6.996809           7.078082            6.868675
# Normal                   7.250000           6.934177            6.803896
#
# Product line   Sports and travel
# Customer type
# Member                  6.817241
# Normal                  7.025316

# %%
t2 = pd.pivot_table(data=df,index = ['Customer type'], columns = ['Product line'], values = 'Unit price', aggfunc='mean')

# %%
t2
# Out:
# Product line   Electronic accessories  Fashion accessories  \
# Customer type
# Member                      55.278205            56.776395
# Normal                      52.087717            57.506304
#
# Product line   Food and beverages  Health and beauty  Home and lifestyle  \
# Customer type
# Member                  58.080638          56.069041           55.120241
# Normal                  53.574500          53.732152           55.528961
#
# Product line   Sports and travel
# Customer type
# Member                 55.604943
# Normal                 58.522152

# %%
plt.figure(figsize=(11,6))
plt.style.use('ggplot')
ax = sns.countplot(x = "Customer type", hue = "Product line", data = df)
ax.set_title(label = "Customer type wrt Product Line", fontsize = 25)
ax.set_xlabel(xlabel = "t1", fontsize = 16)
ax.set_ylabel(ylabel = "Customer Count", fontsize = 16)
# Out:
# Text(0, 0.5, 'Customer Count')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 496  556-97-7101      C  Naypyitaw        Normal  Female
# 484  493-65-6248      C  Naypyitaw        Member  Female
# 567  651-88-7328      A     Yangon        Normal  Female
# 523  133-14-7229      C  Naypyitaw        Normal    Male
# 970  746-04-1077      B   Mandalay        Member  Female
# ..           ...    ...        ...           ...     ...
# 393  308-47-4913      A     Yangon        Member  Female
# 73   841-35-6630      C  Naypyitaw        Normal  Female
# 433  616-87-0016      B   Mandalay        Normal    Male
# 585  127-47-6963      A     Yangon        Normal    Male
# 84   360-39-5055      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 496  Electronic accessories       63.22         2   6.3220  132.7620
# 484       Sports and travel       36.98        10  18.4900  388.2900
# 567     Fashion accessories       65.74         9  29.5830  621.2430
# ...
